# %% [markdown]
# <a href="https://colab.research.google.com/github/gkh2004/Mini-project-17/blob/main/Hangman_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def hangman():
    word_list = ["python", "hangman", "programming", "developer", "algorithm"]
    word = random.choice(word_list).lower()
    guessed = ["_"] * len(word)
    attempts = 6
    guessed_letters = set()

    print("🎮 Welcome to Hangman!")

    while attempts > 0 and "_" in guessed:
        print("\nWord:", " ".join(guessed))
        print(f"Attempts left: {attempts}")
        print("Guessed letters:", " ".join(sorted(guessed_letters)))
        guess = input("Enter a letter: ").lower()

        if not guess.isalpha() or len(guess) != 1:
            print("Please enter a single alphabet letter.")
            continue

        if guess in guessed_letters:
            print("You already guessed that letter.")
            continue

        guessed_letters.add(guess)

        if guess in word:
            for i, letter in enumerate(word):
                if letter == guess:
                    guessed[i] = guess
            print(f"✅ Good guess: {guess}")
        else:
            attempts -= 1
            print(f"❌ Wrong guess: {guess}")

    print("\nGame Over!")
    if "_" not in guessed:
        print("🎉 Congratulations, you won!")
    else:
        print(f"😢 You lost. The word was '{word}'.")

# Run the game
hangman()
# Out:
# 🎮 Welcome to Hangman!
#
# Word: _ _ _ _ _ _ _ _ _ _ _
# Attempts left: 6
# Guessed letters:
# Enter a letter: W
# ❌ Wrong guess: w
#
# Word: _ _ _ _ _ _ _ _ _ _ _
# Attempts left: 5
# Guessed letters: w
# Enter a letter: a
# ✅ Good guess: a
#
# Word: _ _ _ _ _ a _ _ _ _ _
# Attempts left: 5
# Guessed letters: a w
# Enter a letter: l
# ❌ Wrong guess: l
#
# Word: _ _ _ _ _ a _ _ _ _ _
# Attempts left: 4
# Guessed letters: a l w
# Enter a letter: g
# ✅ Good guess: g
#
# Word: _ _ _ g _ a _ _ _ _ g
# Attempts left: 4
# Guessed letters: a g l w
# Enter a letter: o
# ✅ Good guess: o
#
# Word: _ _ o g _ a _ _ _ _ g
# Attempts left: 4
# Guessed letters: a g l o w
# Enter a letter: r
# ✅ Good guess: r
#
# Word: _ r o g r a _ _ _ _ g
# Attempts left: 4
# Guessed letters: a g l o r w
# Enter a letter: i
# ✅ Good guess: i
#
# Word: _ r o g r a _ _ i _ g
# Attempts left: 4
# Guessed letters: a g i l o r w
# Enter a letter: t
# ❌ Wrong guess: t
#
# Word: _ r o g r a _ _ i _ g
# Attempts left: 3
# ...
